# %%
# pip install scikit-learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# %%
rezultat = make_regression(n_samples = 3, n_features = 1, n_targets = 1)
print(rezultat, type(rezultat))
# Out:
# (array([[-1.30237952],
#        [-2.30510821],
#        [ 0.35912921]]), array([ -85.80801698, -151.87336788,   23.66143282])) <class 'tuple'>

# %%
x, y = rezultat

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
x
# Out:
# array([[-1.30237952],
#        [-2.30510821],
#        [ 0.35912921]])

# %%
print(model.predict(x))
print(y)
# Out:
# [ -85.80801698 -151.87336788   23.66143282]
# [ -85.80801698 -151.87336788   23.66143282]

# %%
model.predict([[-1.30237952]])
# Out:
# array([-85.80801671])

# %%
model.predict([[1]])
# Out:
# array([65.88556975])

# %%
plt.scatter(x, y)
plt.show()

# %%
new_x, new_y = make_regression(n_samples = 20, n_features = 1, n_targets = 1, noise = 10)
plt.scatter(new_x, new_y)
plt.show()

# %%
new_model = LinearRegression()
new_model.fit(new_x, new_y)
# Out:
# LinearRegression()

# %%
pred_y = new_model.predict(new_x)

# %%
plt.scatter(new_x, new_y, c = "red")
plt.plot(new_x, pred_y)
plt.show()

# %%
real_v_prezis = {"y_real":new_y, "y_prezis":pred_y}
df_real_vs_prezis = pd.DataFrame(real_v_prezis)
df_real_vs_prezis["delta"] = df_real_vs_prezis["y_real"] - df_real_vs_prezis["y_prezis"]
df_real_vs_prezis
# Out:
#         y_real    y_prezis      delta
# 0   -32.282279  -39.947033   7.664754
# 1    33.745442   29.186707   4.558736
# 2    -9.917339  -13.146093   3.228754
# 3    23.921027   25.991954  -2.070927
# 4    44.009474   49.508328  -5.498854
# 5    33.570346   22.199999  11.370347
# 6     6.353594    3.349165   3.004429
# 7   -50.727287  -43.155995  -7.571293
# 8    -9.905149  -16.570372   6.665222
# 9    16.364048   22.229939  -5.865891
# 10   44.697556   26.654700  18.042856
# 11  110.818703  108.088845   2.729859
# 12   -9.430436  -14.568910   5.138473
# 13   -8.136788  -17.252197   9.115409
# 14    8.431651   14.677034  -6.245383
# 15   13.840559   35.981631 -22.141071
# 16   24.440697   23.580239   0.860458
# 17  -42.411144  -21.295614 -21.115530
# 18  -37.235834  -35.307919  -1.927915
# 19   -5.324889   -5.382456   0.057567
